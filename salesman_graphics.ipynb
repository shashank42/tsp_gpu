# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

route = pd.read_csv("./mona_lisa_best_trip.csv")

# %%
route.duplicated(subset = 'location')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 971     False
# 972     False
# 973     False
# 974     False
# 975     False
# 976     False
# 977     False
# 978     False
# 979     False
# 980     False
# 981     False
# 982     False
# 983     False
# 984     False
# 985     False
# 986     False
# 987     False
# 988     False
# 989     False
# 990     False
# 991     False
# 992     False
# 993     False
# 994     False
# 995     False
# 996     False
# 997     False
# 998     False
# 999     False
# 1000     True
# dtype: bool

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 15)
mpl.rcParams['agg.path.chunksize'] = 10000
fig = plt.scatter(route.loc[:,"coordinate_x"],route.loc[:, "coordinate_y"], s = 1)
#plt.ylim((0,20000))
#plt.xlim((0,20000))
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pylab.rcParams['figure.figsize'] = (15, 15)
mpl.rcParams['agg.path.chunksize'] = 10000
fig = plt.plot(route.loc[:,"coordinate_x"],route.loc[:, "coordinate_y"], linewidth = 1)
#plt.ylim((0,20000))
#plt.xlim((0,20000))
plt.show()
