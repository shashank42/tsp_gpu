# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

route = pd.read_csv("./mona-lisa100K_trip.csv")

# %%
print route[route.duplicated(subset = 'location', keep = False)]
# Out:
#         location  coordinate_x  coordinate_y
# 0              0       14991.0        8390.0
# 100000         0       14991.0        8390.0

# %%
pylab.rcParams['figure.figsize'] = (15, 15)
mpl.rcParams['agg.path.chunksize'] = 10000
fig = plt.scatter(route.loc[:,"coordinate_x"],route.loc[:, "coordinate_y"], s = 1)
#plt.ylim((0,20000))
#plt.xlim((0,20000))
plt.show()

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 15)
mpl.rcParams['agg.path.chunksize'] = 10000
fig = plt.plot(route.loc[:,"coordinate_x"],route.loc[:, "coordinate_y"], linewidth = .02)
#plt.ylim((0,20000))
#plt.xlim((0,20000))
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
