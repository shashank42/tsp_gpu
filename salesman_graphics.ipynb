# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

route = pd.read_csv("./mona_lisa_best_trip.csv")

# %%
# Check for duplicated locations
#route.duplicated(subset = 'location')
route.columns
# Out:
# Index([u'location', u'coordinate_x', u'coordinate_y'], dtype='object')

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 15)
mpl.rcParams['agg.path.chunksize'] = 10000
fig = plt.scatter(route.loc[:,"coordinate_x"],route.loc[:, "coordinate_y"], s = 1)
plt.ylim((0,20000))
plt.xlim((0,20000))
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pylab.rcParams['figure.figsize'] = (15, 15)
mpl.rcParams['agg.path.chunksize'] = 10000
fig = plt.plot(route.loc[:,"coordinate_x"],route.loc[:, "coordinate_y"], linewidth = .01)
plt.ylim((0,20000))
plt.xlim((0,20000))
plt.show()
