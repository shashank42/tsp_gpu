# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

route = pd.read_csv("./data/lrb744710_trip_best.csv")
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
print route[route.duplicated(subset = 'location', keep = False)]
#print route
# Out:
#         location  coordinate_x  coordinate_y
# 0              0           0.0        1553.0
# 744710         0           0.0        1553.0

# %%
pylab.rcParams['figure.figsize'] = (15, 15)
mpl.rcParams['agg.path.chunksize'] = 10000
fig = plt.scatter(route.loc[:,"coordinate_x"],route.loc[:, "coordinate_y"], s = 1)
#plt.ylim((0,20000))
#plt.xlim((0,20000))
plt.show()

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 15)
mpl.rcParams['agg.path.chunksize'] = 10000
fig = plt.plot(route.loc[:,"coordinate_x"],route.loc[:, "coordinate_y"], linewidth = .5)
plt.ylim((1500,2000))
plt.xlim((1500,2000))
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# time = 10742 (2.98 hours)
#
# Original Loss is:  12,174,138,277,888
#
# Optimized Loss is:    186,105,217,024
